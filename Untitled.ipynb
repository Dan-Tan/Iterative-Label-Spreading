# %%
from iterLS import ILS
import numpy as np

# %%
d1 = np.random.normal([0, 0], [0.1, 0.1], [200, 2])
d2 = np.random.normal([10, 10], [0.1, 0.1], [200, 2])
data = np.concatenate((d1, d2), axis = 0)
test = ILS()
test.label_spreading(data)
a, b = test.segmentation([200])
test.label_spreading(data, a, b)

# %%
test.plot_rmin(cluster_colouring = True, max_rmin = 0.2)
